# %%
# !nvidia-smi
# Out:
# Fri Dec 12 22:06:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   38C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Training

# %% [markdown]
# ## Preparation

# %%
# !git clone https://github.com/upiupiup/projectakhir-dl-sam-pytorch.git
# Out:
# Cloning into 'projectakhir-dl-sam-pytorch'...
# remote: Enumerating objects: 257, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 257 (delta 93), reused 80 (delta 72), pack-reused 140 (from 3)
# Receiving objects: 100% (257/257), 162.80 MiB | 46.14 MiB/s, done.
# Resolving deltas: 100% (115/115), done.
# Updating files: 100% (44/44), done.

# %%
# %cd projectakhir-dl-sam-pytorch
# Out:
# /kaggle/working/projectakhir-dl-sam-pytorch

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torchvision

# %%
# !ls
# Out:
# data  example  img  LICENSE  __pycache__  README.md  requirements.txt  sam.py

# %% [markdown]
# Helper Function

# %%
import os

PROJECT = "/kaggle/working/projectakhir-dl-sam-pytorch"
datasets = ["cifar10", "svhn"]
optimizers = ["sgd", "sam_sgd"]
seeds = [0, 1, 2]
epochs = 20

def run_once(dataset, optimizer, seed, epochs):
    out_dir = f"/kaggle/working/results/{dataset}_{optimizer}_seed{seed}"
    os.makedirs(out_dir, exist_ok=True)

    cmd = f"""
PYTHONPATH={PROJECT} \
python {PROJECT}/example/train.py \
    --dataset {dataset} \
    --model resnet18 \
    --optimizer {optimizer} \
    --epochs {epochs} \
    --batch_size 512 \
    --seed {seed} \
    --output_dir {out_dir}
    """
    print(f"\n=== RUN: dataset={dataset}, opt={optimizer}, seed={seed} ===")
    os.system(cmd)

# %% [markdown]
# ## Sanity Check

# %%
# !PYTHONPATH=/kaggle/working/projectakhir-dl-sam-pytorch \
  python example/train.py \
    --dataset cifar10 \
    --model resnet18 \
    --optimizer sgd \
    --epochs 10 \
    --batch_size 128 \
    --output_dir /kaggle/working/results

# %% [markdown]
# ## CIFAR10

# %% [markdown]
# ### SGD

# %%
for opt in ["sgd", "sam_sgd"]:
    run_once("cifar10", opt, seed, epochs=30)
# Out:
# === RUN: dataset=cifar10, opt=sgd, seed=0 ===
# 100%|██████████| 170M/170M [00:02<00:00, 82.6MB/s]
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      1.9265  │     18.56 %  ┃   1.000e-01  │   01:11 min  ┃┈████████████████████████▒┈┈┈┨      1.5003  │     28.22 %  ┃
# ┃           1  ┃      1.3376  │     34.46 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.2005  │     41.33 %  ┃
# ┃           2  ┃      1.1726  │     43.29 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      1.0478  │     49.06 %  ┃
# ┃           3  ┃      1.0310  │     50.72 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      1.0533  │     49.57 %  ┃
# ┃           4  ┃      0.9327  │     56.02 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.9513  │     56.16 %  ┃
# ┃           5  ┃      0.8395  │     60.74 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7321  │     66.13 %  ┃
# ┃           6  ┃      0.7510  │     65.16 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7921  │     64.01 %  ┃
# ┃           7  ┃      0.6771  │     68.83 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.6773  │     69.26 %  ┃
# ┃           8  ┃      0.6104  │     72.02 %  ┃   1.000e-01  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.6484  │     70.76 %  ┃
# ┃           9  ┃      0.4934  │     77.82 %  ┃   2.000e-02  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.4541  │     80.32 %  ┃
# ┃          10  ┃      0.4581  │     79.58 %  ┃   2.000e-02  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.4562  │     80.10 %  ┃
# ┃          11  ┃      0.4371  │     80.56 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4311  │     80.96 %  ┃
# ┃          12  ┃      0.4230  │     81.02 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4099  │     82.00 %  ┃
# ┃          13  ┃      0.4074  │     81.98 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4168  │     81.91 %  ┃
# ┃          14  ┃      0.3984  │     82.13 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4593  │     79.34 %  ┃
# ┃          15  ┃      0.3867  │     82.84 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4101  │     81.80 %  ┃
# ┃          16  ┃      0.3702  │     83.57 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4027  │     82.37 %  ┃
# ┃          17  ┃      0.3642  │     83.89 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3636  │     84.20 %  ┃
# ┃          18  ┃      0.3219  │     85.95 %  ┃   4.000e-03  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.3202  │     86.13 %  ┃
# ┃          19  ┃      0.3068  │     86.70 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3211  │     86.15 %  ┃
# ┃          20  ┃      0.3012  │     87.08 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3177  │     86.02 %  ┃
# ┃          21  ┃      0.2980  │     87.22 %  ┃   4.000e-03  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.3133  │     86.44 %  ┃
# ┃          22  ┃      0.2950  │     87.32 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3116  │     86.56 %  ┃
# ┃          23  ┃      0.2900  │     87.39 %  ┃   4.000e-03  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.3078  │     86.88 %  ┃
# ┃          24  ┃      0.2826  │     87.85 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3016  │     87.11 %  ┃
# ┃          25  ┃      0.2780  │     88.07 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2999  │     87.05 %  ┃
# ┃          26  ┃      0.2798  │     87.87 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3007  │     87.10 %  ┃
# ┃          27  ┃      0.2793  │     88.11 %  ┃   8.000e-04  │   00:58 min  ┃┈████████████████████████▒┈┈┈┨      0.2995  │     87.16 %  ┃
# ┃          28  ┃      0.2760  │     88.19 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2993  │     87.10 %  ┃
# ┃          29  ┃      0.2737  │     88.10 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2975  │     87.25 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_sgd, seed=0 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      1.9576  │     16.08 %  ┃   1.000e-01  │   01:55 min  ┃┈████████████████████████▒┈┈┈┨      1.5388  │     21.79 %  ┃
# ┃           1  ┃      1.4599  │     27.48 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.3110  │     34.93 %  ┃
# ┃           2  ┃      1.2778  │     37.05 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.1900  │     42.23 %  ┃
# ┃           3  ┃      1.1588  │     43.65 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.0571  │     49.91 %  ┃
# ┃           4  ┃      1.0558  │     49.42 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.0056  │     52.33 %  ┃
# ┃           5  ┃      0.9577  │     54.59 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.8622  │     59.20 %  ┃
# ┃           6  ┃      0.8647  │     59.51 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.7709  │     63.53 %  ┃
# ┃           7  ┃      0.7789  │     63.77 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.7370  │     66.07 %  ┃
# ┃           8  ┃      0.7089  │     67.29 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.6827  │     68.59 %  ┃
# ┃           9  ┃      0.6015  │     72.48 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.5483  │     75.33 %  ┃
# ┃          10  ┃      0.5670  │     74.17 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.5345  │     76.18 %  ┃
# ┃          11  ┃      0.5461  │     75.24 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.5199  │     76.78 %  ┃
# ┃          12  ┃      0.5256  │     76.30 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4911  │     78.23 %  ┃
# ┃          13  ┃      0.5066  │     77.09 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.5015  │     77.67 %  ┃
# ┃          14  ┃      0.4933  │     77.78 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4825  │     78.69 %  ┃
# ┃          15  ┃      0.4754  │     78.66 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4558  │     79.68 %  ┃
# ┃          16  ┃      0.4608  │     79.34 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4842  │     78.50 %  ┃
# ┃          17  ┃      0.4474  │     79.81 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4460  │     80.18 %  ┃
# ┃          18  ┃      0.4101  │     81.81 %  ┃   4.000e-03  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.3897  │     83.16 %  ┃
# ┃          19  ┃      0.3982  │     82.50 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3908  │     83.04 %  ┃
# ┃          20  ┃      0.3919  │     82.74 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3854  │     83.37 %  ┃
# ┃          21  ┃      0.3910  │     82.81 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3780  │     83.66 %  ┃
# ┃          22  ┃      0.3846  │     83.33 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3743  │     83.87 %  ┃
# ┃          23  ┃      0.3803  │     83.35 %  ┃   4.000e-03  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.3688  │     83.91 %  ┃
# ┃          24  ┃      0.3743  │     83.77 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3650  │     84.07 %  ┃
# ┃          25  ┃      0.3693  │     83.92 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3633  │     83.96 %  ┃
# ┃          26  ┃      0.3719  │     83.81 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3632  │     84.18 %  ┃
# ┃          27  ┃      0.3701  │     83.82 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3628  │     84.27 %  ┃
# ┃          28  ┃      0.3690  │     83.96 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3619  │     84.25 %  ┃
# ┃          29  ┃      0.3655  │     84.30 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3607  │     84.37 %  ┃

# %%
# %cd /kaggle/working
# !zip -r results_30epoch.zip results/
# Out:
# /kaggle/working
#   adding: results/ (stored 0%)
#   adding: results/cifar10_sam_sgd_seed0/ (stored 0%)
#   adding: results/cifar10_sam_sgd_seed0/checkpoints/ (stored 0%)
#   adding: results/cifar10_sam_sgd_seed0/checkpoints/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_best.pt (deflated 8%)
#   adding: results/cifar10_sam_sgd_seed0/epochs/ (stored 0%)
#   adding: results/cifar10_sam_sgd_seed0/epochs/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_20251212-223849.csv (deflated 60%)
#   adding: results/cifar10_sam_sgd_seed0/summary.csv (deflated 39%)
#   adding: results/cifar10_sgd_seed0/ (stored 0%)
#   adding: results/cifar10_sgd_seed0/checkpoints/ (stored 0%)
#   adding: results/cifar10_sgd_seed0/checkpoints/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed0_best.pt (deflated 7%)
#   adding: results/cifar10_sgd_seed0/epochs/ (stored 0%)
#   adding: results/cifar10_sgd_seed0/epochs/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed0_20251212-220702.csv (deflated 60%)
#   adding: results/cifar10_sgd_seed0/summary.csv (deflated 37%)

# %% [markdown]
# ### AdamW

# %%
for opt in ["adamw", "sam_adamw"]:
    run_once("cifar10", opt, seed, epochs=20)

# %%
# %cd /kaggle/working
# !zip -r adamw_results.zip results/cifar10_adamw_seed0 results/cifar10_sam_adamw_seed0

# %% [markdown]
# ### Seed

# %%
for seed in [0, 1, 2]:
    for opt in ["sgd", "sam_sgd"]:
        run_once("cifar10", opt, seed, epochs=30)
# Out:
# === RUN: dataset=cifar10, opt=sgd, seed=0 ===
# 100%|██████████| 170M/170M [00:01<00:00, 101MB/s]
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      1.9031  │     18.56 %  ┃   1.000e-01  │   01:13 min  ┃┈████████████████████████▒┈┈┈┨      1.5222  │     26.70 %  ┃
# ┃           1  ┃      1.3208  │     35.08 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.1995  │     41.06 %  ┃
# ┃           2  ┃      1.1277  │     45.54 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.0216  │     51.54 %  ┃
# ┃           3  ┃      0.9854  │     53.57 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.9006  │     57.73 %  ┃
# ┃           4  ┃      0.8533  │     60.13 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.9284  │     57.83 %  ┃
# ┃           5  ┃      0.7754  │     64.39 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.7009  │     67.82 %  ┃
# ┃           6  ┃      0.6918  │     68.09 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.7124  │     67.09 %  ┃
# ┃           7  ┃      0.6194  │     71.72 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.6699  │     69.95 %  ┃
# ┃           8  ┃      0.5551  │     74.76 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.5814  │     73.93 %  ┃
# ┃           9  ┃      0.4495  │     80.09 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.4086  │     82.31 %  ┃
# ┃          10  ┃      0.4192  │     81.24 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.4079  │     82.41 %  ┃
# ┃          11  ┃      0.4036  │     82.05 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.4040  │     82.58 %  ┃
# ┃          12  ┃      0.3895  │     82.75 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.3696  │     83.97 %  ┃
# ┃          13  ┃      0.3762  │     83.42 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.3552  │     84.27 %  ┃
# ┃          14  ┃      0.3674  │     83.77 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.3706  │     83.67 %  ┃
# ┃          15  ┃      0.3542  │     84.39 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.3867  │     82.95 %  ┃
# ┃          16  ┃      0.3455  │     84.74 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.4189  │     81.77 %  ┃
# ┃          17  ┃      0.3347  │     85.22 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.3568  │     84.58 %  ┃
# ┃          18  ┃      0.2983  │     87.13 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2978  │     87.12 %  ┃
# ┃          19  ┃      0.2863  │     87.68 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2962  │     87.24 %  ┃
# ┃          20  ┃      0.2806  │     87.94 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2958  │     87.46 %  ┃
# ┃          21  ┃      0.2793  │     88.17 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2883  │     87.67 %  ┃
# ┃          22  ┃      0.2760  │     88.05 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2883  │     87.47 %  ┃
# ┃          23  ┃      0.2705  │     88.25 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2805  │     87.79 %  ┃
# ┃          24  ┃      0.2627  │     88.83 %  ┃   8.000e-04  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2766  │     88.05 %  ┃
# ┃          25  ┃      0.2575  │     89.01 %  ┃   8.000e-04  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2763  │     88.11 %  ┃
# ┃          26  ┃      0.2594  │     88.92 %  ┃   8.000e-04  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2759  │     88.13 %  ┃
# ┃          27  ┃      0.2598  │     88.94 %  ┃   8.000e-04  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2755  │     88.20 %  ┃
# ┃          28  ┃      0.2557  │     89.13 %  ┃   8.000e-04  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2751  │     88.34 %  ┃
# ┃          29  ┃      0.2550  │     89.07 %  ┃   8.000e-04  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.2739  │     88.34 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_sgd, seed=0 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      1.9758  │     15.17 %  ┃   1.000e-01  │   01:55 min  ┃┈████████████████████████▒┈┈┈┨      1.5504  │     23.92 %  ┃
# ┃           1  ┃      1.4597  │     27.97 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.3261  │     35.25 %  ┃
# ┃           2  ┃      1.2653  │     37.88 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.1836  │     42.60 %  ┃
# ┃           3  ┃      1.1445  │     44.49 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.0732  │     48.74 %  ┃
# ┃           4  ┃      1.0426  │     50.19 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      1.0392  │     50.85 %  ┃
# ┃           5  ┃      0.9484  │     55.15 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.9104  │     57.53 %  ┃
# ┃           6  ┃      0.8550  │     59.94 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.8180  │     62.52 %  ┃
# ┃           7  ┃      0.7761  │     63.94 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.7934  │     63.27 %  ┃
# ┃           8  ┃      0.7112  │     67.32 %  ┃   1.000e-01  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.7120  │     67.34 %  ┃
# ┃           9  ┃      0.6048  │     72.37 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.5440  │     75.26 %  ┃
# ┃          10  ┃      0.5684  │     74.05 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.5535  │     74.99 %  ┃
# ┃          11  ┃      0.5455  │     75.42 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.5359  │     75.87 %  ┃
# ┃          12  ┃      0.5244  │     76.42 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4994  │     77.55 %  ┃
# ┃          13  ┃      0.5038  │     77.37 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4979  │     77.20 %  ┃
# ┃          14  ┃      0.4903  │     77.88 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4700  │     79.07 %  ┃
# ┃          15  ┃      0.4734  │     78.94 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4653  │     79.08 %  ┃
# ┃          16  ┃      0.4551  │     79.68 %  ┃   2.000e-02  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.4418  │     80.41 %  ┃
# ┃          17  ┃      0.4425  │     80.29 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4246  │     81.18 %  ┃
# ┃          18  ┃      0.4080  │     82.05 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3858  │     83.12 %  ┃
# ┃          19  ┃      0.3938  │     82.89 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3872  │     82.98 %  ┃
# ┃          20  ┃      0.3893  │     82.94 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3821  │     83.33 %  ┃
# ┃          21  ┃      0.3888  │     83.06 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3718  │     83.89 %  ┃
# ┃          22  ┃      0.3840  │     83.20 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3718  │     83.88 %  ┃
# ┃          23  ┃      0.3785  │     83.30 %  ┃   4.000e-03  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3662  │     84.04 %  ┃
# ┃          24  ┃      0.3718  │     83.82 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3618  │     84.27 %  ┃
# ┃          25  ┃      0.3686  │     83.95 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3600  │     84.25 %  ┃
# ┃          26  ┃      0.3704  │     83.95 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3596  │     84.29 %  ┃
# ┃          27  ┃      0.3690  │     83.96 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3592  │     84.40 %  ┃
# ┃          28  ┃      0.3680  │     83.91 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.3589  │     84.43 %  ┃
# ┃          29  ┃      0.3651  │     84.16 %  ┃   8.000e-04  │   01:36 min  ┃┈████████████████████████▒┈┈┈┨      0.3569  │     84.54 %  ┃
#
# === RUN: dataset=cifar10, opt=sgd, seed=1 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      1.9461  │     16.81 %  ┃   1.000e-01  │   01:16 min  ┃┈████████████████████████▒┈┈┈┨      1.5341  │     23.36 %  ┃
# ┃           1  ┃      1.3716  │     30.87 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.2601  │     37.52 %  ┃
# ┃           2  ┃      1.1825  │     42.30 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      1.1165  │     46.39 %  ┃
# ┃           3  ┃      1.0368  │     50.34 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      1.0415  │     51.12 %  ┃
# ┃           4  ┃      0.9013  │     57.47 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.8696  │     59.34 %  ┃
# ┃           5  ┃      0.7974  │     63.04 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7979  │     63.86 %  ┃
# ┃           6  ┃      0.7109  │     67.16 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7598  │     65.84 %  ┃
# ┃           7  ┃      0.6256  │     71.65 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7858  │     64.40 %  ┃
# ┃           8  ┃      0.5677  │     74.47 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7073  │     68.52 %  ┃
# ┃           9  ┃      0.4508  │     79.92 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4240  │     81.36 %  ┃
# ┃          10  ┃      0.4184  │     81.36 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4135  │     82.09 %  ┃
# ┃          11  ┃      0.4025  │     82.24 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3936  │     82.59 %  ┃
# ┃          12  ┃      0.3883  │     82.77 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3920  │     82.75 %  ┃
# ┃          13  ┃      0.3750  │     83.45 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3848  │     82.85 %  ┃
# ┃          14  ┃      0.3615  │     84.16 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3713  │     83.74 %  ┃
# ┃          15  ┃      0.3508  │     84.52 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3698  │     83.67 %  ┃
# ┃          16  ┃      0.3403  │     84.97 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3901  │     83.23 %  ┃
# ┃          17  ┃      0.3286  │     85.50 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3747  │     84.03 %  ┃
# ┃          18  ┃      0.2947  │     87.14 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2967  │     87.25 %  ┃
# ┃          19  ┃      0.2814  │     87.77 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2941  │     87.37 %  ┃
# ┃          20  ┃      0.2788  │     87.98 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2948  │     87.17 %  ┃
# ┃          21  ┃      0.2717  │     88.30 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2936  │     87.57 %  ┃
# ┃          22  ┃      0.2670  │     88.55 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2944  │     87.51 %  ┃
# ┃          23  ┃      0.2673  │     88.48 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2870  │     87.57 %  ┃
# ┃          24  ┃      0.2568  │     89.00 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2798  │     87.95 %  ┃
# ┃          25  ┃      0.2535  │     89.21 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2801  │     87.81 %  ┃
# ┃          26  ┃      0.2533  │     89.13 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2795  │     87.95 %  ┃
# ┃          27  ┃      0.2515  │     89.23 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2787  │     88.00 %  ┃
# ┃          28  ┃      0.2505  │     89.21 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2770  │     87.91 %  ┃
# ┃          29  ┃      0.2480  │     89.51 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2774  │     88.00 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_sgd, seed=1 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.1217  │     13.10 %  ┃   1.000e-01  │   01:54 min  ┃┈████████████████████████▒┈┈┈┨      1.6741  │     18.40 %  ┃
# ┃           1  ┃      1.5899  │     20.66 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.4991  │     25.93 %  ┃
# ┃           2  ┃      1.4603  │     27.81 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.3981  │     31.40 %  ┃
# ┃           3  ┃      1.3744  │     32.64 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.2829  │     36.47 %  ┃
# ┃           4  ┃      1.2906  │     36.86 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.2153  │     40.74 %  ┃
# ┃           5  ┃      1.2056  │     41.37 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.1412  │     44.47 %  ┃
# ┃           6  ┃      1.1285  │     45.25 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.1002  │     48.00 %  ┃
# ┃           7  ┃      1.0599  │     48.98 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.0750  │     48.87 %  ┃
# ┃           8  ┃      0.9931  │     52.60 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.0004  │     52.54 %  ┃
# ┃           9  ┃      0.8975  │     57.65 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.8281  │     61.09 %  ┃
# ┃          10  ┃      0.8549  │     59.54 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.7938  │     63.43 %  ┃
# ┃          11  ┃      0.8230  │     61.38 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.7824  │     63.61 %  ┃
# ┃          12  ┃      0.7973  │     62.73 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.7488  │     65.18 %  ┃
# ┃          13  ┃      0.7688  │     64.20 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.7352  │     66.41 %  ┃
# ┃          14  ┃      0.7450  │     65.39 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.7051  │     67.89 %  ┃
# ┃          15  ┃      0.7181  │     67.14 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.6908  │     68.41 %  ┃
# ┃          16  ┃      0.6974  │     67.92 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.6691  │     69.39 %  ┃
# ┃          17  ┃      0.6695  │     69.19 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.6803  │     69.39 %  ┃
# ┃          18  ┃      0.6328  │     71.18 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5912  │     72.96 %  ┃
# ┃          19  ┃      0.6153  │     72.09 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5835  │     73.47 %  ┃
# ┃          20  ┃      0.6102  │     72.32 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5741  │     73.93 %  ┃
# ┃          21  ┃      0.6013  │     72.63 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5698  │     74.19 %  ┃
# ┃          22  ┃      0.5917  │     73.18 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5632  │     74.42 %  ┃
# ┃          23  ┃      0.5838  │     73.41 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5649  │     74.48 %  ┃
# ┃          24  ┃      0.5783  │     74.03 %  ┃   8.000e-04  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5506  │     75.33 %  ┃
# ┃          25  ┃      0.5711  │     74.35 %  ┃   8.000e-04  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5475  │     75.55 %  ┃
# ┃          26  ┃      0.5697  │     74.35 %  ┃   8.000e-04  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5466  │     75.51 %  ┃
# ┃          27  ┃      0.5700  │     74.33 %  ┃   8.000e-04  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5445  │     75.54 %  ┃
# ┃          28  ┃      0.5683  │     74.29 %  ┃   8.000e-04  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5440  │     75.56 %  ┃
# ┃          29  ┃      0.5630  │     74.74 %  ┃   8.000e-04  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5426  │     75.51 %  ┃
#
# === RUN: dataset=cifar10, opt=sgd, seed=2 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      1.8847  │     20.43 %  ┃   1.000e-01  │   01:16 min  ┃┈████████████████████████▒┈┈┈┨      1.3667  │     32.24 %  ┃
# ┃           1  ┃      1.2935  │     36.89 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.2045  │     41.76 %  ┃
# ┃           2  ┃      1.1403  │     45.23 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      1.1564  │     45.80 %  ┃
# ┃           3  ┃      1.0311  │     50.90 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      1.0361  │     51.24 %  ┃
# ┃           4  ┃      0.9114  │     57.43 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.9249  │     57.19 %  ┃
# ┃           5  ┃      0.8112  │     62.70 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7824  │     63.92 %  ┃
# ┃           6  ┃      0.7416  │     65.92 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7257  │     67.52 %  ┃
# ┃           7  ┃      0.6762  │     69.05 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.6410  │     71.04 %  ┃
# ┃           8  ┃      0.6186  │     71.87 %  ┃   1.000e-01  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.7908  │     66.35 %  ┃
# ┃           9  ┃      0.5005  │     77.63 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4493  │     80.04 %  ┃
# ┃          10  ┃      0.4630  │     79.34 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4418  │     80.80 %  ┃
# ┃          11  ┃      0.4399  │     80.50 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4333  │     80.77 %  ┃
# ┃          12  ┃      0.4247  │     81.29 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4040  │     82.31 %  ┃
# ┃          13  ┃      0.4102  │     81.82 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4318  │     81.24 %  ┃
# ┃          14  ┃      0.4003  │     82.41 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.4060  │     81.71 %  ┃
# ┃          15  ┃      0.3819  │     83.16 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3918  │     82.70 %  ┃
# ┃          16  ┃      0.3744  │     83.58 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3861  │     83.20 %  ┃
# ┃          17  ┃      0.3612  │     84.33 %  ┃   2.000e-02  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3713  │     83.70 %  ┃
# ┃          18  ┃      0.3219  │     86.19 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3263  │     85.95 %  ┃
# ┃          19  ┃      0.3081  │     86.78 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3153  │     86.44 %  ┃
# ┃          20  ┃      0.3020  │     86.87 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3187  │     86.37 %  ┃
# ┃          21  ┃      0.2979  │     87.15 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3104  │     86.60 %  ┃
# ┃          22  ┃      0.2959  │     87.29 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3126  │     86.85 %  ┃
# ┃          23  ┃      0.2903  │     87.63 %  ┃   4.000e-03  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3077  │     86.92 %  ┃
# ┃          24  ┃      0.2814  │     88.03 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3008  │     87.34 %  ┃
# ┃          25  ┃      0.2776  │     88.28 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3011  │     87.18 %  ┃
# ┃          26  ┃      0.2763  │     88.33 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.3005  │     87.39 %  ┃
# ┃          27  ┃      0.2775  │     88.20 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2995  │     87.40 %  ┃
# ┃          28  ┃      0.2729  │     88.53 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2980  │     87.39 %  ┃
# ┃          29  ┃      0.2752  │     88.30 %  ┃   8.000e-04  │   00:57 min  ┃┈████████████████████████▒┈┈┈┨      0.2987  │     87.36 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_sgd, seed=2 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.0649  │     15.72 %  ┃   1.000e-01  │   01:54 min  ┃┈████████████████████████▒┈┈┈┨      1.5291  │     23.43 %  ┃
# ┃           1  ┃      1.4814  │     25.97 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.3502  │     33.70 %  ┃
# ┃           2  ┃      1.3366  │     33.79 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.2500  │     37.57 %  ┃
# ┃           3  ┃      1.2290  │     39.85 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.1885  │     43.38 %  ┃
# ┃           4  ┃      1.1460  │     44.45 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.0789  │     48.52 %  ┃
# ┃           5  ┃      1.0685  │     48.55 %  ┃   1.000e-01  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      1.0125  │     51.16 %  ┃
# ┃           6  ┃      0.9865  │     53.15 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.9367  │     55.56 %  ┃
# ┃           7  ┃      0.8946  │     57.99 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.8595  │     59.23 %  ┃
# ┃           8  ┃      0.8183  │     61.74 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.8364  │     61.70 %  ┃
# ┃           9  ┃      0.7119  │     67.04 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.6493  │     70.44 %  ┃
# ┃          10  ┃      0.6768  │     69.00 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.6340  │     71.12 %  ┃
# ┃          11  ┃      0.6514  │     70.06 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.6011  │     72.19 %  ┃
# ┃          12  ┃      0.6275  │     71.24 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5885  │     73.30 %  ┃
# ┃          13  ┃      0.6113  │     72.06 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.5767  │     73.76 %  ┃
# ┃          14  ┃      0.5937  │     72.85 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5592  │     74.51 %  ┃
# ┃          15  ┃      0.5692  │     74.15 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5645  │     74.60 %  ┃
# ┃          16  ┃      0.5534  │     75.03 %  ┃   2.000e-02  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.5087  │     76.83 %  ┃
# ┃          17  ┃      0.5292  │     76.18 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.5053  │     77.82 %  ┃
# ┃          18  ┃      0.4887  │     78.27 %  ┃   4.000e-03  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4569  │     79.87 %  ┃
# ┃          19  ┃      0.4779  │     78.80 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.4496  │     79.98 %  ┃
# ┃          20  ┃      0.4700  │     79.16 %  ┃   4.000e-03  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4431  │     80.41 %  ┃
# ┃          21  ┃      0.4642  │     79.40 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.4376  │     80.59 %  ┃
# ┃          22  ┃      0.4585  │     79.68 %  ┃   4.000e-03  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.4405  │     80.38 %  ┃
# ┃          23  ┃      0.4539  │     79.81 %  ┃   4.000e-03  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4334  │     80.71 %  ┃
# ┃          24  ┃      0.4475  │     80.12 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4237  │     81.35 %  ┃
# ┃          25  ┃      0.4399  │     80.60 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4230  │     81.45 %  ┃
# ┃          26  ┃      0.4374  │     80.73 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4217  │     81.38 %  ┃
# ┃          27  ┃      0.4376  │     80.64 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4204  │     81.38 %  ┃
# ┃          28  ┃      0.4381  │     80.73 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4197  │     81.45 %  ┃
# ┃          29  ┃      0.4385  │     80.71 %  ┃   8.000e-04  │   01:35 min  ┃┈████████████████████████▒┈┈┈┨      0.4186  │     81.53 %  ┃

# %%
# %cd /kaggle/working
# !zip -r results_3seed_cifar10_sgd_samsgd.zip results/
# Out:
# /kaggle/working
# updating: results/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed0/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed0/checkpoints/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed0/checkpoints/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_best.pt (deflated 8%)
# updating: results/cifar10_sam_sgd_seed0/epochs/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed0/epochs/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_20251213-000213.csv (deflated 60%)
# updating: results/cifar10_sam_sgd_seed0/epochs/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_20251212-223849.csv (deflated 60%)
# updating: results/cifar10_sam_sgd_seed0/summary.csv (deflated 54%)
# updating: results/cifar10_sgd_seed2/ (stored 0%)
# updating: results/cifar10_sgd_seed2/checkpoints/ (stored 0%)
# updating: results/cifar10_sgd_seed2/checkpoints/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed2_best.pt (deflated 7%)
# updating: results/cifar10_sgd_seed2/epochs/ (stored 0%)
# updating: results/cifar10_sgd_seed2/epochs/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed2_20251213-021414.csv (deflated 60%)
# updating: results/cifar10_sgd_seed2/summary.csv (deflated 36%)
# updating: results/cifar10_sgd_seed1/ (stored 0%)
# updating: results/cifar10_sgd_seed1/checkpoints/ (stored 0%)
# updating: results/cifar10_sgd_seed1/checkpoints/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed1_best.pt (deflated 7%)
# updating: results/cifar10_sgd_seed1/epochs/ (stored 0%)
# updating: results/cifar10_sgd_seed1/epochs/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed1_20251213-005300.csv (deflated 60%)
# updating: results/cifar10_sgd_seed1/summary.csv (deflated 37%)
# updating: results/cifar10_sgd_seed0/ (stored 0%)
# updating: results/cifar10_sgd_seed0/checkpoints/ (stored 0%)
# updating: results/cifar10_sgd_seed0/checkpoints/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed0_best.pt (deflated 7%)
# updating: results/cifar10_sgd_seed0/epochs/ (stored 0%)
# updating: results/cifar10_sgd_seed0/epochs/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed0_20251212-220702.csv (deflated 60%)
# updating: results/cifar10_sgd_seed0/epochs/cifar10_resnet18_sgd_lr0.1_wd0.0005_bs512_seed0_20251212-233114.csv (deflated 60%)
# updating: results/cifar10_sgd_seed0/summary.csv (deflated 50%)
# updating: results/cifar10_sam_sgd_seed2/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed2/checkpoints/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed2/checkpoints/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed2_best.pt (deflated 8%)
# updating: results/cifar10_sam_sgd_seed2/epochs/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed2/epochs/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed2_20251213-024542.csv (deflated 60%)
# updating: results/cifar10_sam_sgd_seed2/summary.csv (deflated 39%)
# updating: results/cifar10_sam_sgd_seed1/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed1/checkpoints/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed1/checkpoints/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed1_best.pt (deflated 8%)
# updating: results/cifar10_sam_sgd_seed1/epochs/ (stored 0%)
# updating: results/cifar10_sam_sgd_seed1/epochs/cifar10_resnet18_sam_sgd_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed1_20251213-012425.csv (deflated 60%)
# updating: results/cifar10_sam_sgd_seed1/summary.csv (deflated 39%)

# %%
for seed in [1, 2]:
    for opt in ["adamw", "sam_sgd"]:
        run_once("cifar10", opt, seed, epochs=30)

# %% [markdown]
# ## SVHN

# %% [markdown]
# ### SGD

# %%
for opt in ["sgd", "sam_sgd"]:
    run_once("svhn", opt, seed, epochs=20)
# Out:
# === RUN: dataset=svhn, opt=sgd, seed=0 ===
# Traceback (most recent call last):
#   File "/kaggle/working/projectakhir-dl-sam-pytorch/example/train.py", line 7, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2108, in <module>
#     from torch import _VF as _VF, functional as functional  # usort: skip
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 9, in <module>
#     from torch.nn import (
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/attention/__init__.py", line 7, in <module>
#     import torch.backends.cuda
#   File "/usr/local/lib/python3.11/dist-packages/torch/backends/__init__.py", line 60, in <module>
#     from torch.backends import (
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1130, in get_data
# KeyboardInterrupt
# === RUN: dataset=svhn, opt=sam_sgd, seed=0 ===
# Traceback (most recent call last):
#   File "/kaggle/working/projectakhir-dl-sam-pytorch/example/train.py", line 7, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2222, in <module>
#     from torch import quantization as quantization  # usort: skip
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/quantization/__init__.py", line 10, in <module>
#     from .quantize_jit import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1165, in _find_and_load
# KeyboardInterrupt

# %%
# %cd /kaggle/working/projectakhir-dl-sam-pytorch

import sys

ROOT = "/kaggle/working/projectakhir-dl-sam-pytorch"
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

from example.data.svhn import Svhn

# bikin loader SVHN
svhn = Svhn(batch_size=128, threads=0)

train_loader = svhn.train
test_loader  = svhn.test

print("Jumlah sample TRAIN :", len(train_loader.dataset))
print("Jumlah sample TEST  :", len(test_loader.dataset))

# cek contoh batch
images, labels = next(iter(train_loader))
print("Batch image shape :", images.shape)   # [B, 3, 32, 32]
print("Batch label shape :", labels.shape)
# Out:
# /kaggle/working/projectakhir-dl-sam-pytorch
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_277/1987174645.py in <cell line: 0>()
#       7     sys.path.insert(0, ROOT)
#       8
# ----> 9 from example.data.svhn import Svhn
#      10
#      11 # bikin loader SVHN
#
# ModuleNotFoundError: No module named 'example.data'; 'example' is not a package

# %% [markdown]
# ### AdamW
