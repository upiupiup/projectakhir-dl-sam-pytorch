# %%
# !nvidia-smi
# Out:
# Sat Dec 13 03:45:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0             32W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Training

# %% [markdown]
# ## Preparation

# %%
# !git clone https://github.com/upiupiup/projectakhir-dl-sam-pytorch.git
# Out:
# fatal: destination path 'projectakhir-dl-sam-pytorch' already exists and is not an empty directory.

# %%
# %cd projectakhir-dl-sam-pytorch
# Out:
# /kaggle/working/projectakhir-dl-sam-pytorch

# %%
pip install pillow

# %%
import torch
import torchvision

# %%
# !ls

# %% [markdown]
# Helper Function

# %%
import os

PROJECT = "/kaggle/working/projectakhir-dl-sam-pytorch"
datasets = ["cifar10", "svhn"]
optimizers = ["sgd", "sam_sgd"]
seeds = [0, 1, 2]
epochs = 20

def run_once(dataset, optimizer, seed, epochs):
    out_dir = f"/kaggle/working/results/{dataset}_{optimizer}_seed{seed}"
    os.makedirs(out_dir, exist_ok=True)

    cmd = f"""
PYTHONPATH={PROJECT} \
python {PROJECT}/example/train.py \
    --dataset {dataset} \
    --model resnet18 \
    --optimizer {optimizer} \
    --epochs {epochs} \
    --batch_size 512 \
    --seed {seed} \
    --output_dir {out_dir}
    """
    print(f"\n=== RUN: dataset={dataset}, opt={optimizer}, seed={seed} ===")
    os.system(cmd)

# %% [markdown]
# ## Sanity Check

# %%
# !PYTHONPATH=/kaggle/working/projectakhir-dl-sam-pytorch \
  python example/train.py \
    --dataset cifar10 \
    --model resnet18 \
    --optimizer sgd \
    --epochs 10 \
    --batch_size 128 \
    --output_dir /kaggle/working/results

# %% [markdown]
# ## CIFAR10

# %% [markdown]
# ### SGD

# %%
for opt in ["sgd", "sam_sgd"]:
    run_once("cifar10", opt, seed, epochs=30)

# %%
# %cd /kaggle/working
# !zip -r results_30epoch.zip results/

# %% [markdown]
# ### AdamW

# %%
for opt in ["adamw", "sam_adamw"]:
    run_once("cifar10", opt, seed, epochs=20)

# %%
# %cd /kaggle/working
# !zip -r adamw_results.zip results/cifar10_adamw_seed0 results/cifar10_sam_adamw_seed0

# %% [markdown]
# ### Seed

# %%
for seed in [0, 1, 2]:
    for opt in ["sgd", "sam_sgd"]:
        run_once("cifar10", opt, seed, epochs=30)

# %%
# %cd /kaggle/working
# !zip -r results_3seed_cifar10_sgd_samsgd.zip results/

# %%
for seed in [0]:
    for opt in ["adamw", "sam_adamw"]:
        run_once("cifar10", opt, seed, epochs=30)
# Out:
# === RUN: dataset=cifar10, opt=adamw, seed=0 ===
# 100%|██████████| 170M/170M [00:01<00:00, 98.9MB/s]
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.4243  │     16.50 %  ┃   1.000e-01  │   01:10 min  ┃┈████████████████████████▒┈┈┈┨      1.5580  │     22.49 %  ┃
# ┃           1  ┃      1.4899  │     23.73 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.4069  │     29.03 %  ┃
# ┃           2  ┃      1.4091  │     27.99 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.4059  │     30.46 %  ┃
# ┃           3  ┃      1.3453  │     33.25 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.4882  │     31.91 %  ┃
# ┃           4  ┃      1.2486  │     39.14 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.2112  │     42.60 %  ┃
# ┃           5  ┃      1.1606  │     43.93 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.1982  │     45.79 %  ┃
# ┃           6  ┃      1.0571  │     49.17 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.0053  │     52.39 %  ┃
# ┃           7  ┃      0.9792  │     53.23 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.1156  │     48.22 %  ┃
# ┃           8  ┃      0.8979  │     57.40 %  ┃   1.000e-01  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      1.0017  │     53.18 %  ┃
# ┃           9  ┃      0.7750  │     63.43 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.7144  │     66.09 %  ┃
# ┃          10  ┃      0.7347  │     65.43 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.7194  │     66.86 %  ┃
# ┃          11  ┃      0.7132  │     66.28 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.7703  │     65.15 %  ┃
# ┃          12  ┃      0.6941  │     67.41 %  ┃   2.000e-02  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.8095  │     63.80 %  ┃
# ┃          13  ┃      0.6745  │     68.77 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6855  │     67.98 %  ┃
# ┃          14  ┃      0.6540  │     69.33 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6755  │     69.32 %  ┃
# ┃          15  ┃      0.6312  │     70.80 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6108  │     72.12 %  ┃
# ┃          16  ┃      0.6029  │     72.09 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6144  │     71.84 %  ┃
# ┃          17  ┃      0.5893  │     72.94 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6151  │     72.19 %  ┃
# ┃          18  ┃      0.5302  │     75.78 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4989  │     77.09 %  ┃
# ┃          19  ┃      0.5106  │     76.70 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4906  │     77.27 %  ┃
# ┃          20  ┃      0.5008  │     77.20 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4970  │     77.18 %  ┃
# ┃          21  ┃      0.4963  │     77.35 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4750  │     78.06 %  ┃
# ┃          22  ┃      0.4905  │     77.78 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4780  │     77.74 %  ┃
# ┃          23  ┃      0.4786  │     78.32 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4646  │     78.90 %  ┃
# ┃          24  ┃      0.4664  │     78.89 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4466  │     79.54 %  ┃
# ┃          25  ┃      0.4634  │     78.63 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4462  │     79.76 %  ┃
# ┃          26  ┃      0.4610  │     78.99 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4449  │     79.77 %  ┃
# ┃          27  ┃      0.4570  │     79.22 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4438  │     79.77 %  ┃
# ┃          28  ┃      0.4551  │     79.37 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4418  │     79.89 %  ┃
# ┃          29  ┃      0.4528  │     79.50 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4393  │     80.16 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_adamw, seed=0 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.4963  │     11.06 %  ┃   1.000e-01  │   01:52 min  ┃┈████████████████████████▒┈┈┈┨      1.7017  │     17.40 %  ┃
# ┃           1  ┃      1.5589  │     23.08 %  ┃   1.000e-01  │   01:32 min  ┃┈████████████████████████▒┈┈┈┨      1.4768  │     26.54 %  ┃
# ┃           2  ┃      1.4021  │     31.97 %  ┃   1.000e-01  │   01:32 min  ┃┈████████████████████████▒┈┈┈┨      1.3332  │     35.81 %  ┃
# ┃           3  ┃      1.3141  │     36.18 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.4095  │     35.29 %  ┃
# ┃           4  ┃      1.2550  │     39.18 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.3706  │     35.03 %  ┃
# ┃           5  ┃      1.2155  │     41.38 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.1968  │     43.33 %  ┃
# ┃           6  ┃      1.1777  │     43.39 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.1620  │     44.24 %  ┃
# ┃           7  ┃      1.1437  │     45.25 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.1560  │     46.26 %  ┃
# ┃           8  ┃      1.0852  │     48.60 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2763  │     43.67 %  ┃
# ┃           9  ┃      1.0053  │     52.39 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.9497  │     55.01 %  ┃
# ┃          10  ┃      0.9839  │     53.40 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9316  │     55.93 %  ┃
# ┃          11  ┃      0.9673  │     54.23 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9163  │     56.87 %  ┃
# ┃          12  ┃      0.9434  │     55.38 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9050  │     58.04 %  ┃
# ┃          13  ┃      0.9271  │     56.53 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9172  │     57.57 %  ┃
# ┃          14  ┃      0.9072  │     57.30 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8432  │     60.88 %  ┃
# ┃          15  ┃      0.8914  │     58.07 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.8220  │     62.09 %  ┃
# ┃          16  ┃      0.8690  │     59.42 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9654  │     56.24 %  ┃
# ┃          17  ┃      0.8498  │     60.37 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8296  │     61.89 %  ┃
# ┃          18  ┃      0.8059  │     62.45 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7364  │     65.90 %  ┃
# ┃          19  ┃      0.7840  │     63.64 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7306  │     66.38 %  ┃
# ┃          20  ┃      0.7768  │     63.81 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7321  │     66.62 %  ┃
# ┃          21  ┃      0.7717  │     64.14 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7255  │     67.00 %  ┃
# ┃          22  ┃      0.7613  │     64.57 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7150  │     67.11 %  ┃
# ┃          23  ┃      0.7547  │     64.96 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7284  │     66.60 %  ┃
# ┃          24  ┃      0.7431  │     65.65 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6950  │     67.86 %  ┃
# ┃          25  ┃      0.7372  │     65.72 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6939  │     68.11 %  ┃
# ┃          26  ┃      0.7361  │     65.98 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6930  │     68.20 %  ┃
# ┃          27  ┃      0.7362  │     65.99 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6914  │     68.11 %  ┃
# ┃          28  ┃      0.7352  │     65.80 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6907  │     68.39 %  ┃
# ┃          29  ┃      0.7324  │     66.14 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6882  │     68.43 %  ┃

# %%
# %cd /kaggle/working/results

# !zip -r cifar10_sam_adamw_seed0.zip \
    cifar10_sam_adamw_seed0
# Out:
# /kaggle/working/results
#   adding: cifar10_sam_adamw_seed0/ (stored 0%)
#   adding: cifar10_sam_adamw_seed0/checkpoints/ (stored 0%)
#   adding: cifar10_sam_adamw_seed0/checkpoints/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_best.pt (deflated 9%)
#   adding: cifar10_sam_adamw_seed0/epochs/ (stored 0%)
#   adding: cifar10_sam_adamw_seed0/epochs/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_20251213-033926.csv (deflated 32%)
#   adding: cifar10_sam_adamw_seed0/epochs/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed0_20251213-070235.csv (deflated 59%)
#   adding: cifar10_sam_adamw_seed0/summary.csv (deflated 39%)

# %%
for seed in [1, 2]:
    for opt in ["adamw", "sam_adamw"]:
        run_once("cifar10", opt, seed, epochs=30)
# Out:
# === RUN: dataset=cifar10, opt=adamw, seed=1 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.6235  │     12.62 %  ┃   1.000e-01  │   01:15 min  ┃┈████████████████████████▒┈┈┈┨      1.6152  │     18.62 %  ┃
# ┃           1  ┃      1.5254  │     22.34 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.4733  │     25.35 %  ┃
# ┃           2  ┃      1.4296  │     28.28 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.3664  │     34.52 %  ┃
# ┃           3  ┃      1.3455  │     33.88 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.2789  │     38.76 %  ┃
# ┃           4  ┃      1.2631  │     38.48 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.2613  │     41.42 %  ┃
# ┃           5  ┃      1.1859  │     42.25 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.1697  │     43.54 %  ┃
# ┃           6  ┃      1.1149  │     46.09 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.1925  │     44.12 %  ┃
# ┃           7  ┃      1.0471  │     49.84 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.9589  │     54.52 %  ┃
# ┃           8  ┃      0.9690  │     53.97 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.0847  │     50.46 %  ┃
# ┃           9  ┃      0.8428  │     60.71 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7804  │     63.96 %  ┃
# ┃          10  ┃      0.8021  │     62.49 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7424  │     65.94 %  ┃
# ┃          11  ┃      0.7715  │     63.71 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7328  │     66.33 %  ┃
# ┃          12  ┃      0.7477  │     65.08 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7095  │     67.77 %  ┃
# ┃          13  ┃      0.7162  │     66.70 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6679  │     69.52 %  ┃
# ┃          14  ┃      0.6881  │     68.11 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6956  │     68.21 %  ┃
# ┃          15  ┃      0.6635  │     69.39 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6403  │     71.18 %  ┃
# ┃          16  ┃      0.6394  │     70.38 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6412  │     70.97 %  ┃
# ┃          17  ┃      0.6073  │     71.93 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6176  │     71.56 %  ┃
# ┃          18  ┃      0.5558  │     74.50 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5068  │     77.43 %  ┃
# ┃          19  ┃      0.5323  │     75.53 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5038  │     77.66 %  ┃
# ┃          20  ┃      0.5247  │     76.14 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4932  │     77.98 %  ┃
# ┃          21  ┃      0.5175  │     76.35 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.4923  │     77.88 %  ┃
# ┃          22  ┃      0.5072  │     76.87 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.4908  │     78.21 %  ┃
# ┃          23  ┃      0.5021  │     76.94 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4824  │     78.29 %  ┃
# ┃          24  ┃      0.4872  │     77.86 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4605  │     79.51 %  ┃
# ┃          25  ┃      0.4796  │     78.45 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4587  │     79.59 %  ┃
# ┃          26  ┃      0.4786  │     78.30 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4574  │     79.84 %  ┃
# ┃          27  ┃      0.4784  │     78.00 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4553  │     79.97 %  ┃
# ┃          28  ┃      0.4748  │     78.34 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4545  │     79.77 %  ┃
# ┃          29  ┃      0.4719  │     78.50 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4533  │     79.82 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_adamw, seed=1 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.6188  │     11.15 %  ┃   1.000e-01  │   01:53 min  ┃┈████████████████████████▒┈┈┈┨      1.7385  │     11.97 %  ┃
# ┃           1  ┃      1.6022  │     19.45 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.4671  │     26.85 %  ┃
# ┃           2  ┃      1.4666  │     26.83 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.3933  │     31.43 %  ┃
# ┃           3  ┃      1.3818  │     32.46 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2937  │     38.26 %  ┃
# ┃           4  ┃      1.2867  │     37.78 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2512  │     40.57 %  ┃
# ┃           5  ┃      1.2332  │     40.60 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2221  │     40.83 %  ┃
# ┃           6  ┃      1.1887  │     42.51 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2075  │     42.30 %  ┃
# ┃           7  ┃      1.1509  │     44.65 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2369  │     43.30 %  ┃
# ┃           8  ┃      1.1032  │     46.97 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.0867  │     49.17 %  ┃
# ┃           9  ┃      1.0063  │     52.16 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9395  │     55.58 %  ┃
# ┃          10  ┃      0.9728  │     53.90 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9213  │     55.97 %  ┃
# ┃          11  ┃      0.9464  │     55.22 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8962  │     57.72 %  ┃
# ┃          12  ┃      0.9213  │     56.40 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8964  │     58.00 %  ┃
# ┃          13  ┃      0.8894  │     58.07 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8388  │     60.34 %  ┃
# ┃          14  ┃      0.8561  │     59.54 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.9089  │     57.91 %  ┃
# ┃          15  ┃      0.8325  │     61.03 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8011  │     63.31 %  ┃
# ┃          16  ┃      0.8043  │     62.25 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.8133  │     63.13 %  ┃
# ┃          17  ┃      0.7702  │     63.88 %  ┃   2.000e-02  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.7598  │     64.70 %  ┃
# ┃          18  ┃      0.7179  │     66.60 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6691  │     69.00 %  ┃
# ┃          19  ┃      0.6986  │     67.46 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6699  │     68.94 %  ┃
# ┃          20  ┃      0.6902  │     67.86 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6612  │     69.72 %  ┃
# ┃          21  ┃      0.6804  │     68.22 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6532  │     69.74 %  ┃
# ┃          22  ┃      0.6712  │     68.88 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6391  │     70.90 %  ┃
# ┃          23  ┃      0.6680  │     69.13 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6388  │     71.05 %  ┃
# ┃          24  ┃      0.6523  │     69.87 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6205  │     71.93 %  ┃
# ┃          25  ┃      0.6447  │     70.24 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6194  │     72.01 %  ┃
# ┃          26  ┃      0.6406  │     70.55 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6181  │     71.88 %  ┃
# ┃          27  ┃      0.6429  │     70.44 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6173  │     72.08 %  ┃
# ┃          28  ┃      0.6374  │     70.56 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6151  │     72.15 %  ┃
# ┃          29  ┃      0.6354  │     70.82 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6097  │     72.41 %  ┃
#
# === RUN: dataset=cifar10, opt=adamw, seed=2 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.5645  │     13.10 %  ┃   1.000e-01  │   01:15 min  ┃┈████████████████████████▒┈┈┈┨      1.6378  │     19.43 %  ┃
# ┃           1  ┃      1.5810  │     20.84 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.5307  │     23.75 %  ┃
# ┃           2  ┃      1.4847  │     24.66 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.4646  │     27.41 %  ┃
# ┃           3  ┃      1.3849  │     29.90 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.3273  │     34.15 %  ┃
# ┃           4  ┃      1.2856  │     36.20 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.2556  │     37.75 %  ┃
# ┃           5  ┃      1.1866  │     42.18 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.1304  │     45.37 %  ┃
# ┃           6  ┃      1.0960  │     47.64 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      1.0661  │     49.30 %  ┃
# ┃           7  ┃      1.0175  │     51.77 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.9362  │     55.77 %  ┃
# ┃           8  ┃      0.9306  │     56.14 %  ┃   1.000e-01  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.9537  │     56.20 %  ┃
# ┃           9  ┃      0.8119  │     62.02 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7419  │     65.75 %  ┃
# ┃          10  ┃      0.7673  │     64.27 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7235  │     66.57 %  ┃
# ┃          11  ┃      0.7447  │     65.27 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7148  │     66.82 %  ┃
# ┃          12  ┃      0.7222  │     66.51 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.7232  │     67.03 %  ┃
# ┃          13  ┃      0.7018  │     67.23 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6700  │     68.59 %  ┃
# ┃          14  ┃      0.6800  │     68.38 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6645  │     68.97 %  ┃
# ┃          15  ┃      0.6626  │     69.05 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6309  │     71.22 %  ┃
# ┃          16  ┃      0.6436  │     70.26 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6257  │     71.57 %  ┃
# ┃          17  ┃      0.6210  │     71.31 %  ┃   2.000e-02  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.6063  │     72.83 %  ┃
# ┃          18  ┃      0.5731  │     73.54 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5338  │     75.70 %  ┃
# ┃          19  ┃      0.5578  │     74.15 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5291  │     76.35 %  ┃
# ┃          20  ┃      0.5502  │     74.57 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5223  │     76.71 %  ┃
# ┃          21  ┃      0.5397  │     75.10 %  ┃   4.000e-03  │   00:56 min  ┃┈████████████████████████▒┈┈┈┨      0.5186  │     76.63 %  ┃
# ┃          22  ┃      0.5342  │     75.60 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5129  │     77.19 %  ┃
# ┃          23  ┃      0.5289  │     75.64 %  ┃   4.000e-03  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.5034  │     77.25 %  ┃
# ┃          24  ┃      0.5170  │     76.19 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4919  │     77.91 %  ┃
# ┃          25  ┃      0.5091  │     76.60 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4908  │     77.89 %  ┃
# ┃          26  ┃      0.5041  │     76.79 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4900  │     77.77 %  ┃
# ┃          27  ┃      0.5045  │     76.95 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4890  │     78.12 %  ┃
# ┃          28  ┃      0.5043  │     76.86 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4871  │     78.08 %  ┃
# ┃          29  ┃      0.5028  │     76.94 %  ┃   8.000e-04  │   00:55 min  ┃┈████████████████████████▒┈┈┈┨      0.4884  │     77.97 %  ┃
#
# === RUN: dataset=cifar10, opt=sam_adamw, seed=2 ===
# ┏━━━━━━━━━━━━━━┳━━━━━━━╸T╺╸R╺╸A╺╸I╺╸N╺━━━━━━━┳━━━━━━━╸S╺╸T╺╸A╺╸T╺╸S╺━━━━━━━┳━━━━━━━╸V╺╸A╺╸L╺╸I╺╸D╺━━━━━━━┓
# ┃              ┃              ╷              ┃              ╷              ┃              ╷              ┃
# ┃       epoch  ┃        loss  │    accuracy  ┃        l.r.  │     elapsed  ┃        loss  │    accuracy  ┃
# ┠──────────────╂──────────────┼──────────────╂──────────────┼──────────────╂──────────────┼──────────────┨
# ┃           0  ┃      2.3506  │     15.98 %  ┃   1.000e-01  │   01:53 min  ┃┈████████████████████████▒┈┈┈┨      1.6122  │     21.22 %  ┃
# ┃           1  ┃      1.5237  │     23.56 %  ┃   1.000e-01  │   01:32 min  ┃┈████████████████████████▒┈┈┈┨      1.4149  │     30.04 %  ┃
# ┃           2  ┃      1.3976  │     30.41 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.3297  │     32.27 %  ┃
# ┃           3  ┃      1.3187  │     35.01 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.2502  │     39.13 %  ┃
# ┃           4  ┃      1.2233  │     40.02 %  ┃   1.000e-01  │   01:32 min  ┃┈████████████████████████▒┈┈┈┨      1.1653  │     45.67 %  ┃
# ┃           5  ┃      1.1339  │     45.26 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.1359  │     46.06 %  ┃
# ┃           6  ┃      1.0462  │     49.53 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      1.0084  │     51.33 %  ┃
# ┃           7  ┃      0.9689  │     53.97 %  ┃   1.000e-01  │   01:34 min  ┃┈████████████████████████▒┈┈┈┨      0.9641  │     55.87 %  ┃
# ┃           8  ┃      0.8959  │     57.73 %  ┃   1.000e-01  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      1.0156  │     54.52 %  ┃
# ┃           9  ┃      0.7873  │     63.19 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7143  │     66.39 %  ┃
# ┃          10  ┃      0.7501  │     64.90 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7154  │     67.17 %  ┃
# ┃          11  ┃      0.7261  │     66.11 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6783  │     68.07 %  ┃
# ┃          12  ┃      0.7010  │     67.58 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.7051  │     67.57 %  ┃
# ┃          13  ┃      0.6836  │     67.99 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6571  │     69.82 %  ┃
# ┃          14  ┃      0.6629  │     69.38 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6494  │     70.08 %  ┃
# ┃          15  ┃      0.6477  │     69.82 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6616  │     69.52 %  ┃
# ┃          16  ┃      0.6330  │     70.66 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5917  │     73.07 %  ┃
# ┃          17  ┃      0.6084  │     71.85 %  ┃   2.000e-02  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.6088  │     72.38 %  ┃
# ┃          18  ┃      0.5559  │     74.35 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5246  │     75.98 %  ┃
# ┃          19  ┃      0.5409  │     75.14 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5379  │     75.73 %  ┃
# ┃          20  ┃      0.5342  │     75.50 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5193  │     76.06 %  ┃
# ┃          21  ┃      0.5243  │     75.96 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5109  │     77.07 %  ┃
# ┃          22  ┃      0.5182  │     76.31 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5118  │     76.74 %  ┃
# ┃          23  ┃      0.5149  │     76.58 %  ┃   4.000e-03  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.5101  │     76.64 %  ┃
# ┃          24  ┃      0.5024  │     77.00 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.4828  │     78.06 %  ┃
# ┃          25  ┃      0.4954  │     77.42 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.4811  │     78.38 %  ┃
# ┃          26  ┃      0.4889  │     77.73 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.4810  │     78.33 %  ┃
# ┃          27  ┃      0.4918  │     77.61 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.4815  │     78.27 %  ┃
# ┃          28  ┃      0.4887  │     77.81 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.4782  │     78.63 %  ┃
# ┃          29  ┃      0.4878  │     77.73 %  ┃   8.000e-04  │   01:33 min  ┃┈████████████████████████▒┈┈┈┨      0.4785  │     78.36 %  ┃

# %%
# %cd /kaggle/working/results

# !zip -r cifar10_sam_adamw_seed1_2.zip \
    cifar10_sam_adamw_seed1 \
    cifar10_sam_adamw_seed2
# Out:
# /kaggle/working/results
#   adding: cifar10_sam_adamw_seed1/ (stored 0%)
#   adding: cifar10_sam_adamw_seed1/checkpoints/ (stored 0%)
#   adding: cifar10_sam_adamw_seed1/checkpoints/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed1_best.pt (deflated 9%)
#   adding: cifar10_sam_adamw_seed1/epochs/ (stored 0%)
#   adding: cifar10_sam_adamw_seed1/epochs/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed1_20251213-041648.csv (deflated 60%)
#   adding: cifar10_sam_adamw_seed1/epochs/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed1_20251213-034443.csv (deflated 25%)
#   adding: cifar10_sam_adamw_seed1/summary.csv (deflated 40%)
#   adding: cifar10_sam_adamw_seed2/ (stored 0%)
#   adding: cifar10_sam_adamw_seed2/checkpoints/ (stored 0%)
#   adding: cifar10_sam_adamw_seed2/checkpoints/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed2_best.pt (deflated 9%)
#   adding: cifar10_sam_adamw_seed2/epochs/ (stored 0%)
#   adding: cifar10_sam_adamw_seed2/epochs/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed2_20251213-053657.csv (deflated 59%)
#   adding: cifar10_sam_adamw_seed2/epochs/cifar10_resnet18_sam_adamw_rho0.05_adaptive0_lr0.1_wd0.0005_bs512_seed2_20251213-034408.csv (deflated 25%)
#   adding: cifar10_sam_adamw_seed2/summary.csv (deflated 39%)

# %% [markdown]
# ## SVHN

# %% [markdown]
# ### SGD

# %%
for opt in ["sgd", "sam_sgd"]:
    run_once("svhn", opt, seed, epochs=20)

# %%
# %cd /kaggle/working/projectakhir-dl-sam-pytorch

import sys

ROOT = "/kaggle/working/projectakhir-dl-sam-pytorch"
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

from example.data.svhn import Svhn

# bikin loader SVHN
svhn = Svhn(batch_size=128, threads=0)

train_loader = svhn.train
test_loader  = svhn.test

print("Jumlah sample TRAIN :", len(train_loader.dataset))
print("Jumlah sample TEST  :", len(test_loader.dataset))

# cek contoh batch
images, labels = next(iter(train_loader))
print("Batch image shape :", images.shape)   # [B, 3, 32, 32]
print("Batch label shape :", labels.shape)

# %% [markdown]
# ### AdamW
